# %% [markdown]
# <a href="https://colab.research.google.com/github/bhattaraiarchana/AI-1/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)


df = load_dataset("/content/drive/MyDrive/eda/team_stats_2003_2023.csv")
df.head(5)
# Out:
#    year                  team  wins  losses  win_loss_perc  points  \
# 0  2003  New England Patriots    14       2          0.875     348
# 1  2003        Miami Dolphins    10       6          0.625     311
# 2  2003         Buffalo Bills     6      10          0.375     243
# 3  2003         New York Jets     6      10          0.375     283
# 4  2003      Baltimore Ravens    10       6          0.625     391
#
#    points_opp  points_diff  mov   g  ...  rush_td  rush_yds_per_att  rush_fd  \
# 0         238          110  6.9  16  ...        9               3.4       91
# 1         261           50  3.1  16  ...       14               3.7       99
# 2         279          -36 -2.3  16  ...       13               3.9       96
# 3         299          -16 -1.0  16  ...        8               4.0       78
# 4         281          110  6.9  16  ...       18               4.8      115
#
#    penalties  penalties_yds  pen_fd  score_pct  turnover_pct  exp_pts_tot  \
# ...

# %%
# Categorical data
# countplot
sns.countplot(data=df, x='wins')
df['losses'].value_counts()
# Out:
# 8     84
# 9     73
# 6     69
# 7     68
# 10    67
# 5     57
# 11    54
# 12    53
# 4     48
# 3     36
# 13    24
# 14    19
# 2      9
# 15     5
# 1      3
# 16     2
# 0      1
# Name: losses, dtype: int64

# %%
 # pie chart

df['g'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='g'>

# %%
# Numberical Value

# Histogram treat as categorical data distribution of data

plt.hist(df['wins'])
# Out:
# (array([  6.,  38.,  58., 110.,  81., 149., 126.,  50.,  50.,   4.]),
#  array([ 0. ,  1.6,  3.2,  4.8,  6.4,  8. ,  9.6, 11.2, 12.8, 14.4, 16. ]),
#  <BarContainer object of 10 artists>)

# %%
# Distplot
# probability density function --> The line is kde
# skweness
sns.distplot(df['penalties'])
# Out:
# <ipython-input-64-ded8fa46aacd>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['penalties'])
# <Axes: xlabel='penalties', ylabel='Density'>

# %%
# Boxplot
# 5 number summary
# median , percentile, min=Q1-1.5*IQR, max=Q3+1.5*IQR, IQR = (Q1-Q3), outlier

sns.boxplot(df['wins'])
# Out:
# <Axes: ylabel='wins'>

# %%
df.describe()
# Out:
#               year        wins      losses  win_loss_perc      points  \
# count   672.000000  672.000000  672.000000     672.000000  672.000000
# mean   2013.000000    8.050595    8.050595       0.500246  358.633929
# std       6.059811    3.093255    3.086020       0.191452   72.092050
# min    2003.000000    0.000000    0.000000       0.000000  168.000000
# 25%    2008.000000    6.000000    6.000000       0.375000  305.000000
# 50%    2013.000000    8.000000    8.000000       0.500000  359.000000
# 75%    2018.000000   10.000000   10.000000       0.625000  406.000000
# max    2023.000000   16.000000   16.000000       1.000000  606.000000
#
#        points_opp  points_diff         mov           g  total_yards  ...  \
# count  672.000000   672.000000  352.000000  672.000000   672.000000  ...
# mean   358.633929     0.000000   -0.001136   16.139881  5463.895833  ...
# std     57.889328   100.684601    6.313288    0.347122   628.209466  ...
# ...

# %%
# Bar plot (Numerical - Categorical)
  # average age in pclass
sns.barplot(x='win_loss_perc',y='turnover_pct',hue='rush_yds_per_att',data=df)
# Out:
# <Axes: xlabel='win_loss_perc', ylabel='turnover_pct'>

# %%
#Box plot (Numerical - Categorical)

sns.boxplot(x='wins',y='points',hue='g',data=df)
# Out:
# <Axes: xlabel='wins', ylabel='points'>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# HeatMap (Categorical - Categorical)
sns.heatmap(pd.crosstab(df['rush_td'],df['rush_fd']))
# Out:
# <Axes: xlabel='rush_fd', ylabel='rush_td'>

# %%
df.groupby('g').mean()['losses']*100
# Out:
# <ipython-input-51-4e9294d4f030>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('g').mean()['losses']*100
# g
# 16    796.712803
# 17    856.382979
# Name: losses, dtype: float64
